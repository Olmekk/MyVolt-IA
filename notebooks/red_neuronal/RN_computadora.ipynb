# %%
import pandas as pd
import matplotlib.pyplot as plt
import joblib 
import numpy as np
import os 
from sqlalchemy import create_engine
from urllib.parse import quote_plus 

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

# %matplotlib inline

# %%
DB_USER = "myvolt_admin" 
DB_PASS = "M%R^N!J%IDKS$8@zya4v"
DB_HOST = "myvolt-db.postgres.database.azure.com"
DB_PORT = "5432"
DB_NAME = "postgres" 

DB_PASS_ENCODED = quote_plus(DB_PASS)

try:
    connection_string = f"postgresql+psycopg2://{DB_USER}:{DB_PASS_ENCODED}@{DB_HOST}:{DB_PORT}/{DB_NAME}?sslmode=require"
    engine = create_engine(connection_string)
    
    with engine.connect() as conn:
        print("¡Conexión a Azure PostgreSQL exitosa!")
        
except Exception as e:
    print(f"Error al conectar a Azure: {e}")
# Out:
# ¡Conexión a Azure PostgreSQL exitosa!

# %%
query = """
SELECT time, power_w
FROM consumption_data
WHERE id_device = (
    SELECT id_device 
    FROM devices 
    WHERE mac_address = 'B0:A7:32:34:54:9C'
)
ORDER BY time DESC
LIMIT 5000; 
"""

df = pd.read_sql_query(query, con=engine)

print(f"Se cargaron {len(df)} registros (los más recientes) desde la base de datos.")
df.head()
# Out:
# Se cargaron 4632 registros (los más recientes) desde la base de datos.
#                               time  power_w
# 0 2025-11-10 05:52:50.725431+00:00   604.84
# 1 2025-11-10 05:52:50.521998+00:00   124.24
# 2 2025-11-10 05:52:50.320239+00:00   147.40
# 3 2025-11-10 05:52:50.118596+00:00   171.36
# 4 2025-11-10 05:52:49.916242+00:00   130.88

# %%
datos_para_modelo = df[['power_w']]
scaler = MinMaxScaler()
datos_escalados = scaler.fit_transform(datos_para_modelo)

print("Datos escalados (convertidos de 0 a 1):")
print(datos_escalados[:5])
# Out:
# Datos escalados (convertidos de 0 a 1):
# [[0.93027079]
#  [0.18490028]
#  [0.2208195 ]
#  [0.25797947]
#  [0.19519836]]

# %%
input_layer = Input(shape=(1,))
encoder = Dense(8, activation='relu')(input_layer)
encoder = Dense(4, activation='relu')(encoder) 
decoder = Dense(8, activation='relu')(encoder)
decoder = Dense(1, activation='sigmoid')(decoder) 
autoencoder = Model(inputs=input_layer, outputs=decoder)
autoencoder.compile(optimizer='adam', loss='mae', metrics=['mae'])
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101 (404.00 B)
#  Trainable params: 101 (404.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
historial = autoencoder.fit(
    datos_escalados, 
    datos_escalados, 
    epochs=50,       
    batch_size=32,
    shuffle=True,
    validation_split=0.1 
)

print("¡Autoencoder de Computadora entrenado!")
# Out:
# Epoch 1/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3195 - mae: 0.3195 - val_loss: 0.2905 - val_mae: 0.2905
# Epoch 2/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2195 - mae: 0.2195 - val_loss: 0.1633 - val_mae: 0.1633
# Epoch 3/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0990 - mae: 0.0990 - val_loss: 0.0691 - val_mae: 0.0691
# Epoch 4/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0508 - mae: 0.0508 - val_loss: 0.0449 - val_mae: 0.0449
# Epoch 5/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0427 - mae: 0.0427 - val_loss: 0.0411 - val_mae: 0.0411
# Epoch 6/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0409 - mae: 0.0409 - val_loss: 0.0389 - val_mae: 0.0389
# Epoch 7/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0401 - mae: 0.0401 - val_loss: 0.0379 - val_mae: 0.0379
# Epoch 8/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0387 - mae: 0.0387 - val_loss: 0.0364 - val_mae: 0.0364
# Epoch 9/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0371 - mae: 0.0371 - val_loss: 0.0366 - val_mae: 0.0366
# Epoch 10/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0356 - mae: 0.0356 - val_loss: 0.0331 - val_mae: 0.0331
# Epoch 11/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0333 - mae: 0.0333 - val_loss: 0.0311 - val_mae: 0.0311
# Epoch 12/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0309 - mae: 0.0309 - val_loss: 0.0298 - val_mae: 0.0298
# Epoch 13/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0287 - mae: 0.0287 - val_loss: 0.0268 - val_mae: 0.0268
# Epoch 14/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0266 - mae: 0.0266 - val_loss: 0.0249 - val_mae: 0.0249
# Epoch 15/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0246 - mae: 0.0246 - val_loss: 0.0232 - val_mae: 0.0232
# Epoch 16/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0232 - mae: 0.0232 - val_loss: 0.0216 - val_mae: 0.0216
# Epoch 17/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0214 - mae: 0.0214 - val_loss: 0.0202 - val_mae: 0.0202
# Epoch 18/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0200 - mae: 0.0200 - val_loss: 0.0191 - val_mae: 0.0191
# Epoch 19/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188 - mae: 0.0188 - val_loss: 0.0188 - val_mae: 0.0188
# Epoch 20/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - mae: 0.0182 - val_loss: 0.0166 - val_mae: 0.0166
# Epoch 21/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173 - mae: 0.0173 - val_loss: 0.0183 - val_mae: 0.0183
# Epoch 22/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0162 - mae: 0.0162 - val_loss: 0.0150 - val_mae: 0.0150
# Epoch 23/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0156 - mae: 0.0156 - val_loss: 0.0143 - val_mae: 0.0143
# Epoch 24/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0149 - mae: 0.0149 - val_loss: 0.0137 - val_mae: 0.0137
# Epoch 25/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0147 - mae: 0.0147 - val_loss: 0.0131 - val_mae: 0.0131
# Epoch 26/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0140 - mae: 0.0140 - val_loss: 0.0138 - val_mae: 0.0138
# Epoch 27/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0133 - mae: 0.0133 - val_loss: 0.0138 - val_mae: 0.0138
# Epoch 28/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0132 - mae: 0.0132 - val_loss: 0.0135 - val_mae: 0.0135
# Epoch 29/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0131 - mae: 0.0131 - val_loss: 0.0114 - val_mae: 0.0114
# Epoch 30/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0125 - mae: 0.0125 - val_loss: 0.0112 - val_mae: 0.0112
# Epoch 31/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0122 - mae: 0.0122 - val_loss: 0.0115 - val_mae: 0.0115
# Epoch 32/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0120 - mae: 0.0120 - val_loss: 0.0108 - val_mae: 0.0108
# Epoch 33/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0122 - mae: 0.0122 - val_loss: 0.0106 - val_mae: 0.0106
# Epoch 34/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0120 - mae: 0.0120 - val_loss: 0.0112 - val_mae: 0.0112
# Epoch 35/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0117 - mae: 0.0117 - val_loss: 0.0104 - val_mae: 0.0104
# Epoch 36/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0116 - mae: 0.0116 - val_loss: 0.0105 - val_mae: 0.0105
# Epoch 37/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0113 - mae: 0.0113 - val_loss: 0.0109 - val_mae: 0.0109
# Epoch 38/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0112 - mae: 0.0112 - val_loss: 0.0114 - val_mae: 0.0114
# Epoch 39/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0113 - mae: 0.0113 - val_loss: 0.0103 - val_mae: 0.0103
# Epoch 40/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0111 - mae: 0.0111 - val_loss: 0.0116 - val_mae: 0.0116
# Epoch 41/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0119 - mae: 0.0119 - val_loss: 0.0118 - val_mae: 0.0118
# Epoch 42/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0112 - mae: 0.0112 - val_loss: 0.0109 - val_mae: 0.0109
# Epoch 43/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0110 - mae: 0.0110 - val_loss: 0.0108 - val_mae: 0.0108
# Epoch 44/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0110 - mae: 0.0110 - val_loss: 0.0099 - val_mae: 0.0099
# Epoch 45/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0109 - mae: 0.0109 - val_loss: 0.0107 - val_mae: 0.0107
# Epoch 46/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0109 - mae: 0.0109 - val_loss: 0.0097 - val_mae: 0.0097
# Epoch 47/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0110 - mae: 0.0110 - val_loss: 0.0109 - val_mae: 0.0109
# Epoch 48/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0113 - mae: 0.0113 - val_loss: 0.0098 - val_mae: 0.0098
# Epoch 49/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0107 - mae: 0.0107 - val_loss: 0.0099 - val_mae: 0.0099
# Epoch 50/50
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0107 - mae: 0.0107 - val_loss: 0.0095 - val_mae: 0.0095
# ¡Autoencoder de Computadora entrenado!

# %%
final_error = historial.history['val_loss'][-1]
final_precision_pct = (1 - final_error) * 100

print(f"Resultados del Entrenamiento de la Red Neuronal (Computadora):")
print(f"Error Final (val_loss): {final_error:.6f} (o {final_error*100:.2f}%)")
print(f"Precisión de Reconstrucción Final: {final_precision_pct:.2f}%")
# Out:
# Resultados del Entrenamiento de la Red Neuronal (Computadora):
# Error Final (val_loss): 0.009529 (o 0.95%)
# Precisión de Reconstrucción Final: 99.05%

# %%
datos_reconstruidos = autoencoder.predict(datos_escalados)
errores = mean_absolute_error(datos_escalados.T, datos_reconstruidos.T, multioutput='raw_values')
df['error_nn'] = errores
umbral = np.percentile(df['error_nn'], 98)

print(f"Error de reconstrucción promedio: {np.mean(df['error_nn'])}")
print(f"UMBRAL DE ANOMALÍA (Computadora) establecido en: {umbral}")
# Out:
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Error de reconstrucción promedio: 0.010472569254823755
# UMBRAL DE ANOMALÍA (Computadora) establecido en: 0.07426937874269642

# %%
df['anomalia_nn'] = df['error_nn'] > umbral
df_normal = df[df['anomalia_nn'] == False]
df_anomalo = df[df['anomalia_nn'] == True]

plt.figure(figsize=(15, 7))
# Deberías ver dos nubes azules: una en 5-15W y otra en 100-300W
plt.scatter(df_normal.index, df_normal['power_w'], 
            c='blue', label='Normal (Detectado por NN)', s=10)
plt.scatter(df_anomalo.index, df_anomalo['power_w'], 
            c='red', label='Anomalía (Detectado por NN)', s=30)

plt.title('Detección de Anomalías (Red Neuronal) - Computadora')
plt.xlabel('Índice de Muestra')
plt.ylabel('Potencia (W)')
plt.legend()
plt.show()

# %%
# 1. Definimos las rutas de salida
ruta_modelo_nn = '../neural_network/computadora_autoencoder_v1.h5'
ruta_scaler_nn = '../scaler/computadora_scaler_v1.pkl'

# 2. Nos aseguramos de que las carpetas existan
os.makedirs(os.path.dirname(ruta_modelo_nn), exist_ok=True)
os.makedirs(os.path.dirname(ruta_scaler_nn), exist_ok=True)

# 3. Guardar el modelo de Red Neuronal (formato .h5)
autoencoder.save(ruta_modelo_nn)

# 4. Guardar el escalador (el que convierte de 0-300 a 0-1)
joblib.dump(scaler, ruta_scaler_nn)

print(f"¡Modelo de Computadora guardado en: {ruta_modelo_nn}!")
print(f"¡Escalador de Computadora guardado en: {ruta_scaler_nn}!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ¡Modelo de Computadora guardado en: ../neural_network/computadora_autoencoder_v1.h5!
# ¡Escalador de Computadora guardado en: ../scaler/computadora_scaler_v1.pkl!
