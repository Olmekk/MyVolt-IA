# %%
import pandas as pd
import matplotlib.pyplot as plt
import joblib 
import numpy as np
import os 
from sqlalchemy import create_engine
from urllib.parse import quote_plus 

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

# %matplotlib inline

# %%
DB_USER = "myvolt_admin" 
DB_PASS = "M%R^N!J%IDKS$8@zya4v"
DB_HOST = "myvolt-db.postgres.database.azure.com"
DB_PORT = "5432"
DB_NAME = "postgres" 

DB_PASS_ENCODED = quote_plus(DB_PASS)

try:
    connection_string = f"postgresql+psycopg2://{DB_USER}:{DB_PASS_ENCODED}@{DB_HOST}:{DB_PORT}/{DB_NAME}?sslmode=require"
    engine = create_engine(connection_string)
    
    with engine.connect() as conn:
        print("¡Conexión a Azure PostgreSQL exitosa!")
        
except Exception as e:
    print(f"Error al conectar a Azure: {e}")
# Out:
# ¡Conexión a Azure PostgreSQL exitosa!

# %%
query = """
SELECT time, power_w
FROM consumption_data
WHERE id_device = (
    SELECT id_device 
    FROM devices 
    WHERE mac_address = 'B0:A7:32:34:54:9C'
)
ORDER BY time DESC
LIMIT 5000; 
"""

df = pd.read_sql_query(query, con=engine)

print(f"Se cargaron {len(df)} registros (los más recientes) desde la base de datos.")
df.head()
# Out:
# Se cargaron 4970 registros (los más recientes) desde la base de datos.
#                               time  power_w
# 0 2025-11-10 04:27:30.184448+00:00      0.0
# 1 2025-11-10 04:27:29.970886+00:00      0.0
# 2 2025-11-10 04:27:29.768528+00:00      0.0
# 3 2025-11-10 04:27:29.565939+00:00      0.0
# 4 2025-11-10 04:27:29.363906+00:00      0.0

# %%
datos_para_modelo = df[['power_w']]
scaler = MinMaxScaler()
datos_escalados = scaler.fit_transform(datos_para_modelo)

print("Datos escalados (convertidos de 0 a 1):")
print(datos_escalados[:5])
# Out:
# Datos escalados (convertidos de 0 a 1):
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]]

# %%
input_layer = Input(shape=(1,))
encoder = Dense(8, activation='relu')(input_layer)
encoder = Dense(4, activation='relu')(encoder) 
decoder = Dense(8, activation='relu')(encoder)
decoder = Dense(1, activation='sigmoid')(decoder) 
autoencoder = Model(inputs=input_layer, outputs=decoder)
autoencoder.compile(optimizer='adam', loss='mae', metrics=['mae'])
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │            16 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101 (404.00 B)
#  Trainable params: 101 (404.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
historial = autoencoder.fit(
    datos_escalados, 
    datos_escalados, 
    epochs=50,       
    batch_size=32,
    shuffle=True,
    validation_split=0.1 
)

print("¡Autoencoder de Ventilador entrenado!")
# Out:
# Epoch 1/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3751 - mae: 0.3751 - val_loss: 0.3848 - val_mae: 0.3848
# Epoch 2/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3284 - mae: 0.3284 - val_loss: 0.2982 - val_mae: 0.2982
# Epoch 3/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2157 - mae: 0.2157 - val_loss: 0.1790 - val_mae: 0.1790
# Epoch 4/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1166 - mae: 0.1166 - val_loss: 0.0875 - val_mae: 0.0875
# Epoch 5/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0554 - mae: 0.0554 - val_loss: 0.0427 - val_mae: 0.0427
# Epoch 6/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0328 - mae: 0.0328 - val_loss: 0.0279 - val_mae: 0.0279
# Epoch 7/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0241 - mae: 0.0241 - val_loss: 0.0215 - val_mae: 0.0215
# Epoch 8/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0197 - mae: 0.0197 - val_loss: 0.0175 - val_mae: 0.0175
# Epoch 9/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0171 - mae: 0.0171 - val_loss: 0.0152 - val_mae: 0.0152
# Epoch 10/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0155 - mae: 0.0155 - val_loss: 0.0136 - val_mae: 0.0136
# Epoch 11/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0143 - mae: 0.0143 - val_loss: 0.0126 - val_mae: 0.0126
# Epoch 12/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0135 - mae: 0.0135 - val_loss: 0.0121 - val_mae: 0.0121
# Epoch 13/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0128 - mae: 0.0128 - val_loss: 0.0112 - val_mae: 0.0112
# Epoch 14/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0122 - mae: 0.0122 - val_loss: 0.0108 - val_mae: 0.0108
# Epoch 15/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0118 - mae: 0.0118 - val_loss: 0.0107 - val_mae: 0.0107
# Epoch 16/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0116 - mae: 0.0116 - val_loss: 0.0102 - val_mae: 0.0102
# Epoch 17/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0112 - mae: 0.0112 - val_loss: 0.0096 - val_mae: 0.0096
# Epoch 18/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0109 - mae: 0.0109 - val_loss: 0.0094 - val_mae: 0.0094
# Epoch 19/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0107 - mae: 0.0107 - val_loss: 0.0092 - val_mae: 0.0092
# Epoch 20/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0105 - mae: 0.0105 - val_loss: 0.0088 - val_mae: 0.0088
# Epoch 21/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0102 - mae: 0.0102 - val_loss: 0.0087 - val_mae: 0.0087
# Epoch 22/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0103 - mae: 0.0103 - val_loss: 0.0086 - val_mae: 0.0086
# Epoch 23/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0102 - mae: 0.0102 - val_loss: 0.0086 - val_mae: 0.0086
# Epoch 24/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0100 - mae: 0.0100 - val_loss: 0.0085 - val_mae: 0.0085
# Epoch 25/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0099 - mae: 0.0099 - val_loss: 0.0084 - val_mae: 0.0084
# Epoch 26/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0099 - mae: 0.0099 - val_loss: 0.0082 - val_mae: 0.0082
# Epoch 27/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0097 - mae: 0.0097 - val_loss: 0.0082 - val_mae: 0.0082
# Epoch 28/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0097 - mae: 0.0097 - val_loss: 0.0081 - val_mae: 0.0081
# Epoch 29/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0096 - mae: 0.0096 - val_loss: 0.0083 - val_mae: 0.0083
# Epoch 30/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0096 - mae: 0.0096 - val_loss: 0.0080 - val_mae: 0.0080
# Epoch 31/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0096 - mae: 0.0096 - val_loss: 0.0079 - val_mae: 0.0079
# Epoch 32/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0096 - mae: 0.0096 - val_loss: 0.0079 - val_mae: 0.0079
# Epoch 33/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0096 - mae: 0.0096 - val_loss: 0.0079 - val_mae: 0.0079
# Epoch 34/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0096 - mae: 0.0096 - val_loss: 0.0080 - val_mae: 0.0080
# Epoch 35/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0095 - mae: 0.0095 - val_loss: 0.0078 - val_mae: 0.0078
# Epoch 36/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0095 - mae: 0.0095 - val_loss: 0.0078 - val_mae: 0.0078
# Epoch 37/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0095 - mae: 0.0095 - val_loss: 0.0078 - val_mae: 0.0078
# Epoch 38/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - mae: 0.0094 - val_loss: 0.0078 - val_mae: 0.0078
# Epoch 39/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0095 - mae: 0.0095 - val_loss: 0.0081 - val_mae: 0.0081
# Epoch 40/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0095 - mae: 0.0095 - val_loss: 0.0078 - val_mae: 0.0078
# Epoch 41/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - mae: 0.0094 - val_loss: 0.0078 - val_mae: 0.0078
# Epoch 42/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - mae: 0.0094 - val_loss: 0.0078 - val_mae: 0.0078
# Epoch 43/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - mae: 0.0094 - val_loss: 0.0078 - val_mae: 0.0078
# Epoch 44/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - mae: 0.0094 - val_loss: 0.0078 - val_mae: 0.0078
# Epoch 45/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - mae: 0.0094 - val_loss: 0.0077 - val_mae: 0.0077
# Epoch 46/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - mae: 0.0094 - val_loss: 0.0078 - val_mae: 0.0078
# Epoch 47/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - mae: 0.0094 - val_loss: 0.0078 - val_mae: 0.0078
# Epoch 48/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - mae: 0.0094 - val_loss: 0.0078 - val_mae: 0.0078
# Epoch 49/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - mae: 0.0094 - val_loss: 0.0078 - val_mae: 0.0078
# Epoch 50/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0094 - mae: 0.0094 - val_loss: 0.0077 - val_mae: 0.0077
# ¡Autoencoder de Ventilador entrenado!

# %%
final_error = historial.history['val_loss'][-1]
final_precision_pct = (1 - final_error) * 100

print(f"Resultados del Entrenamiento de la Red Neuronal (Ventilador):")
print(f"Error Final (val_loss): {final_error:.6f} (o {final_error*100:.2f}%)")
print(f"Precisión de Reconstrucción Final: {final_precision_pct:.2f}%")
# Out:
# Resultados del Entrenamiento de la Red Neuronal (Ventilador):
# Error Final (val_loss): 0.007702 (o 0.77%)
# Precisión de Reconstrucción Final: 99.23%

# %%
datos_reconstruidos = autoencoder.predict(datos_escalados)
errores = mean_absolute_error(datos_escalados.T, datos_reconstruidos.T, multioutput='raw_values')
df['error_nn'] = errores
umbral = np.percentile(df['error_nn'], 98)

print(f"Error de reconstrucción promedio: {np.mean(df['error_nn'])}")
print(f"UMBRAL DE ANOMALÍA (Ventilador) establecido en: {umbral}")
# Out:
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Error de reconstrucción promedio: 0.00915677795085238
# UMBRAL DE ANOMALÍA (Ventilador) establecido en: 0.06739936950683599

# %%
df['anomalia_nn'] = df['error_nn'] > umbral
df_normal = df[df['anomalia_nn'] == False]
df_anomalo = df[df['anomalia_nn'] == True]

plt.figure(figsize=(15, 7))
# Deberías ver dos nubes azules: una en 0W y otra en 40-80W
plt.scatter(df_normal.index, df_normal['power_w'], 
            c='blue', label='Normal (Detectado por NN)', s=10)
plt.scatter(df_anomalo.index, df_anomalo['power_w'], 
            c='red', label='Anomalía (Detectado por NN)', s=30)

plt.title('Detección de Anomalías (Red Neuronal) - Ventilador')
plt.xlabel('Índice de Muestra')
plt.ylabel('Potencia (W)')
plt.legend()
plt.show()

# %%
# 1. Definimos las rutas de salida
ruta_modelo_nn = '../neural_network/ventilador_autoencoder_v1.h5'
ruta_scaler_nn = '../scaler/ventilador_scaler_v1.pkl'

# 2. Nos aseguramos de que las carpetas existan
os.makedirs(os.path.dirname(ruta_modelo_nn), exist_ok=True)
os.makedirs(os.path.dirname(ruta_scaler_nn), exist_ok=True)

# 3. Guardar el modelo de Red Neuronal (formato .h5)
autoencoder.save(ruta_modelo_nn)

# 4. Guardar el escalador (el que convierte de 0-80 a 0-1)
joblib.dump(scaler, ruta_scaler_nn)

print(f"¡Modelo de Ventilador guardado en: {ruta_modelo_nn}!")
print(f"¡Escalador de Ventilador guardado en: {ruta_scaler_nn}!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ¡Modelo de Ventilador guardado en: ../neural_network/ventilador_autoencoder_v1.h5!
# ¡Escalador de Ventilador guardado en: ../scaler/ventilador_scaler_v1.pkl!
